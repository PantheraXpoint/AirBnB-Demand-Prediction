# %%
import pandas as pd 
import numpy as np

# %%
raw_path = 'gnn_embeddings/results.txt'
gnn_path = 'raw_embeddings/results.txt'

# %%
with open(raw_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()  # 파일의 모든 줄을 리스트로 읽기

result

for line in lines:
    print(line.strip())  # 개행 문자를 제거하고 출력
# Out:
# -----------------------
# Checkpoint: gat_gemma_nolist_raw_ver_seqlen6_best_checkpoint.pth
# Mode: 1m, SeqLen: 6
# Combined Metrics (6, 6, 424, 3):
# MSE: 0.1515, MAE: 0.1969, RMSE: 0.3892, MAPE: 811.4238
# Metrics for Feature 1 (6, 6, 424, 1):
# MSE: 0.0149, MAE: 0.0985, RMSE: 0.1220, MAPE: 90.3425
# Metrics for Feature 2 (6, 6, 424, 1):
# MSE: 0.4230, MAE: 0.3903, RMSE: 0.6504, MAPE: 2249.2864
# Metrics for Feature 3 (6, 6, 424, 1):
# MSE: 0.0165, MAE: 0.1020, RMSE: 0.1286, MAPE: 94.6421
# -----------------------
# -----------------------
# Checkpoint: gat_gemma_nolist_raw_ver_seqlen6_best_checkpoint.pth
# Mode: 4m, SeqLen: 6
# Combined Metrics (6, 6, 424, 3):
# MSE: 0.1424, MAE: 0.1875, RMSE: 0.3773, MAPE: 668.3770
# Metrics for Feature 1 (6, 6, 424, 1):
# MSE: 0.0202, MAE: 0.1134, RMSE: 0.1422, MAPE: 103.9407
# Metrics for Feature 2 (6, 6, 424, 1):
# MSE: 0.3882, MAE: 0.3406, RMSE: 0.6231, MAPE: 1800.4763
# Metrics for Feature 3 (6, 6, 424, 1):
# ...
